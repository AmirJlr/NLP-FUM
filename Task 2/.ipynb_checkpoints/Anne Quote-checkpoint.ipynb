# %%
# !pip install icrawler
# !pip install deep-translator
# !pip install --upgrade arabic-reshaper
# !pip install python-bidi
# !pip install Pillow
# !pip install thefuzz
# !pip install pyspellchecker

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/12/81/a80d2c430ccd2a227edf3da0f54fefa67a52f92ee7e5676a7431eba575d7/pyspellchecker-0.7.1-py3-none-any.whl
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 435, in _error_catcher
#     yield
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 516, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\USER\anaconda3\lib\http\client.py", line 463, in read
#     n = self.readinto(b)
#   File "C:\Users\USER\anaconda3\lib\http\client.py", line 507, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\USER\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\USER\anaconda3\lib\ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\USER\anaconda3\lib\ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 369, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 348, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 297, in __init__
#     super().__init__(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 162, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 231, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 308, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 438, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 483, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 165, in unpack_url
#     file = get_http_url(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 106, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 147, in __call__
#     for chunk in chunks:
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 573, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 538, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\USER\anaconda3\lib\contextlib.py", line 137, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\USER\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 440, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
#   Downloading pyspellchecker-0.7.1-py3-none-any.whl (2.5 MB)
#      ----                                     0.3/2.5 MB 63.3 kB/s eta 0:00:35

# %%
# import packages:
from icrawler.builtin import GoogleImageCrawler

import warnings 
warnings.filterwarnings('ignore')

from pathlib import Path

from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw 

import re

import pytesseract
from pytesseract import image_to_string
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

from deep_translator import GoogleTranslator

import arabic_reshaper
from bidi.algorithm import get_display

from pynter.pynter import generate_captioned

from thefuzz import fuzz
from thefuzz import process

# %%
# initialize :

max_num = 10
# assign directory
anne_dir = 'anne'    
wallpaper_dir = 'wallpapers'

# fonts!
font_path ='fonts/Roboto-Regular.ttf'

fontFile = "fonts/Sahel-Bold.ttf"

# %%
def get_google_images(keyword, root_dir, max_num): 
    google_crawler = GoogleImageCrawler(storage={'root_dir': root_dir})
    google_crawler.crawl(keyword=keyword, max_num=max_num)
       
    files = Path(root_dir).glob('*')
    
    while len(list(files)) < max_num:
        get_google_images(keyword, root_dir, max_num)
    return files

# %%
files = get_google_images('sky background', 'wallpapers', max_num)
# Out:
# 2023-04-14 12:32:06,846 - INFO - icrawler.crawler - start crawling...
# 2023-04-14 12:32:06,850 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-04-14 12:32:06,853 - INFO - feeder - thread feeder-001 exit
# 2023-04-14 12:32:06,854 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-04-14 12:32:06,858 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-04-14 12:32:08,732 - INFO - parser - parsing result page https://www.google.com/search?q=sky+background&ijn=0&start=0&tbs=&tbm=isch
# 2023-04-14 12:32:14,001 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/531756/pexels-photo-531756.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-pixabay-531756.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/531756/pexels-photo-531756.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-pixabay-531756.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011324399130>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 2
# 2023-04-14 12:32:19,022 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/531756/pexels-photo-531756.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-pixabay-531756.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/531756/pexels-photo-531756.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-pixabay-531756.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011324399460>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 1
# 2023-04-14 12:32:24,036 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/531756/pexels-photo-531756.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-pixabay-531756.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/531756/pexels-photo-531756.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-pixabay-531756.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011324399970>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 0
# 2023-04-14 12:32:24,038 - INFO - downloader - skip downloading file 000001.jpg
# 2023-04-14 12:32:24,039 - INFO - downloader - skip downloading file 000002.jpg
# 2023-04-14 12:32:24,041 - INFO - downloader - skip downloading file 000003.jpg
# 2023-04-14 12:32:24,042 - INFO - downloader - skip downloading file 000004.jpg
# 2023-04-14 12:32:29,048 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/53594/blue-clouds-day-fluffy-53594.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-pixabay-53594.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/53594/blue-clouds-day-fluffy-53594.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-pixabay-53594.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011324399AC0>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 2
# 2023-04-14 12:32:34,059 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/53594/blue-clouds-day-fluffy-53594.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-pixabay-53594.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/53594/blue-clouds-day-fluffy-53594.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-pixabay-53594.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011323B891C0>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 1
# 2023-04-14 12:32:39,073 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/53594/blue-clouds-day-fluffy-53594.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-pixabay-53594.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/53594/blue-clouds-day-fluffy-53594.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-pixabay-53594.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011323B894C0>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 0
# 2023-04-14 12:32:44,085 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/912110/pexels-photo-912110.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-elia-clerici-912110.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/912110/pexels-photo-912110.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-elia-clerici-912110.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011324399D00>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 2
# 2023-04-14 12:32:49,094 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/912110/pexels-photo-912110.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-elia-clerici-912110.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/912110/pexels-photo-912110.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-elia-clerici-912110.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011324399C70>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 1
# 2023-04-14 12:32:54,110 - ERROR - downloader - Exception caught when downloading file https://images.pexels.com/photos/912110/pexels-photo-912110.jpeg?cs\u003dsrgb\u0026dl\u003dpexels-elia-clerici-912110.jpg, error: HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/912110/pexels-photo-912110.jpeg?cs%5Cu003dsrgb%5Cu0026dl%5Cu003dpexels-elia-clerici-912110.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000113243994C0>, 'Connection to images.pexels.com timed out. (connect timeout=5)')), remaining retry times: 0
# 2023-04-14 12:32:54,112 - INFO - downloader - skip downloading file 000005.jpg
# 2023-04-14 12:32:54,114 - INFO - downloader - skip downloading file 000006.jpg
# 2023-04-14 12:32:54,116 - INFO - downloader - skip downloading file 000007.jpg
# 2023-04-14 12:32:54,117 - INFO - downloader - skip downloading file 000008.jpg
# 2023-04-14 12:32:54,119 - INFO - downloader - skip downloading file 000009.jpg
# 2023-04-14 12:32:54,120 - INFO - downloader - skip downloading file 000010.jpg
# 2023-04-14 12:33:00,614 - ERROR - downloader - Exception caught when downloading file https://4kwallpapers.com/images/wallpapers/clear-sky-sunset-dusk-blue-sky-starry-sky-horizon-beach-1920x1080-4044.jpg, error: HTTPSConnectionPool(host='4kwallpapers.com', port=443): Read timed out. (read timeout=5), remaining retry times: 2
# 2023-04-14 12:33:06,858 - ERROR - downloader - Exception caught when downloading file https://4kwallpapers.com/images/wallpapers/clear-sky-sunset-dusk-blue-sky-starry-sky-horizon-beach-1920x1080-4044.jpg, error: HTTPSConnectionPool(host='4kwallpapers.com', port=443): Read timed out. (read timeout=5), remaining retry times: 1
# 2023-04-14 12:33:12,217 - ERROR - downloader - Exception caught when downloading file https://4kwallpapers.com/images/wallpapers/clear-sky-sunset-dusk-blue-sky-starry-sky-horizon-beach-1920x1080-4044.jpg, error: HTTPSConnectionPool(host='4kwallpapers.com', port=443): Read timed out. (read timeout=5), remaining retry times: 0
# 2023-04-14 12:33:14,275 - INFO - downloader - downloaded images reach max num, thread downloader-001 is ready to exit
# 2023-04-14 12:33:14,277 - INFO - downloader - thread downloader-001 exit
# 2023-04-14 12:33:14,317 - INFO - parser - downloaded image reached max num, thread parser-001 is ready to exit
# 2023-04-14 12:33:14,318 - INFO - parser - thread parser-001 exit
# 2023-04-14 12:33:14,395 - INFO - icrawler.crawler - Crawling task done!

# %%
files = get_google_images('Top Anne shirley Quotes', 'anne', max_num)
# Out:
# 2023-04-14 12:33:14,418 - INFO - icrawler.crawler - start crawling...
# 2023-04-14 12:33:14,420 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2023-04-14 12:33:14,421 - INFO - feeder - thread feeder-001 exit
# 2023-04-14 12:33:14,423 - INFO - icrawler.crawler - starting 1 parser threads...
# 2023-04-14 12:33:14,430 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2023-04-14 12:33:16,470 - INFO - parser - parsing result page https://www.google.com/search?q=Anne+shirley+Quotes&ijn=0&start=0&tbs=&tbm=isch
# 2023-04-14 12:33:16,542 - INFO - downloader - skip downloading file 000001.jpg
# 2023-04-14 12:33:16,546 - INFO - downloader - skip downloading file 000002.jpg
# 2023-04-14 12:33:16,547 - INFO - downloader - skip downloading file 000003.jpg
# 2023-04-14 12:33:16,549 - INFO - downloader - skip downloading file 000004.jpg
# 2023-04-14 12:33:16,549 - INFO - downloader - skip downloading file 000005.jpg
# 2023-04-14 12:33:16,551 - INFO - downloader - skip downloading file 000006.jpg
# 2023-04-14 12:33:16,553 - INFO - downloader - skip downloading file 000007.jpg
# 2023-04-14 12:33:16,554 - INFO - downloader - skip downloading file 000008.jpg
# 2023-04-14 12:33:16,556 - INFO - downloader - skip downloading file 000009.jpg
# 2023-04-14 12:33:16,558 - INFO - downloader - skip downloading file 000010.jpg
# 2023-04-14 12:33:21,622 - ERROR - downloader - Exception caught when downloading file https://i.pinimg.com/736x/2f/03/3c/2f033c5dc9af0fb691f9d6038367a0c0.jpg, error: HTTPSConnectionPool(host='i.pinimg.com', port=443): Max retries exceeded with url: /736x/2f/03/3c/2f033c5dc9af0fb691f9d6038367a0c0.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011323F600D0>, 'Connection to i.pinimg.com timed out. (connect timeout=5)')), remaining retry times: 2
# 2023-04-14 12:33:26,635 - ERROR - downloader - Exception caught when downloading file https://i.pinimg.com/736x/2f/03/3c/2f033c5dc9af0fb691f9d6038367a0c0.jpg, error: HTTPSConnectionPool(host='i.pinimg.com', port=443): Max retries exceeded with url: /736x/2f/03/3c/2f033c5dc9af0fb691f9d6038367a0c0.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011323F60370>, 'Connection to i.pinimg.com timed out. (connect timeout=5)')), remaining retry times: 1
# 2023-04-14 12:33:31,649 - ERROR - downloader - Exception caught when downloading file https://i.pinimg.com/736x/2f/03/3c/2f033c5dc9af0fb691f9d6038367a0c0.jpg, error: HTTPSConnectionPool(host='i.pinimg.com', port=443): Max retries exceeded with url: /736x/2f/03/3c/2f033c5dc9af0fb691f9d6038367a0c0.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000011323F60730>, 'Connection to i.pinimg.com timed out. (connect timeout=5)')), remaining retry times: 0
# 2023-04-14 12:33:33,582 - INFO - downloader - downloaded images reach max num, thread downloader-001 is ready to exit
# 2023-04-14 12:33:33,583 - INFO - downloader - thread downloader-001 exit
# 2023-04-14 12:33:33,655 - INFO - parser - downloaded image reached max num, thread parser-001 is ready to exit
# 2023-04-14 12:33:33,656 - INFO - parser - thread parser-001 exit
# 2023-04-14 12:33:34,562 - INFO - icrawler.crawler - Crawling task done!

# %%
# # iterate over files
# anne_files = Path(anne_dir).glob('*')
# wallpaper_files = Path(wallpaper_dir).glob('*')
# counts = range(max_num)



# for c, anne, wall in zip(counts, anne_files, wallpaper_files):
#     text1 = re.sub('\n', ' ', image_to_string(Image.open(anne)))
#     print(text1)
#     print('----------')
    
#     text2 = re.sub("[^a-zA-Z]", " ", text1)
#     text2= re.sub('[^\S\r\n]{2,}', ' ', text2)
#     print(text2)
#     print('----------')
    
#     translated = re.sub('[a-zA-Z]','', GoogleTranslator(source='auto', target='fa').translate(text2))
#     print(translated)
#     print('*********************************')

#     # this was a 400x400 jpg file
#     imageFile = wall
#     image = Image.open(imageFile)

#     # first you must prepare your text (you dont need this step for english text)
#     text = translated
#     reshaped_text = arabic_reshaper.reshape(text)    # correct its shape
#     bidi_text = get_display(reshaped_text)           # correct its direction
    
#     width  = image.width
#     height = image.height
#     img_center = (width/2,height/2)

#     # start drawing on image
#     draw = ImageDraw.Draw(image)
#     draw.text(img_center, bidi_text, (255,255,0), font=font, align='right')
    
#     # save it
#     image.save(f'imgs/{c}.jpg')

# %%
# iterate over files
anne_files = Path(anne_dir).glob('*')
wallpaper_files = Path(wallpaper_dir).glob('*')
counts = range(max_num)


for c, anne, wall in zip(counts, anne_files, wallpaper_files):
    text1 = re.sub('\n', ' ', image_to_string(Image.open(anne)))
    print(text1)
    print('----------')
    
    text2 = re.sub("[^a-zA-Z]", " ", text1)
    text2= re.sub('[^\S\r\n]{2,}', ' ', text2)
    print(text2)
    print('----------')
    
    translated = re.sub('[a-zA-Z]','', GoogleTranslator(source='auto', target='fa').translate(text2))
    print(translated)
    print('*********************************')

    # this was a 400x400 jpg file
    imageFile = wall
    image = Image.open(imageFile)

    # first you must prepare your text (you dont need this step for english text)
    text = translated
    reshaped_text = arabic_reshaper.reshape(text)    # correct its shape
    bidi_text = get_display(reshaped_text)           # correct its direction
    
    width  = image.width
    height = image.height
    img_center = (width/2,height/2)

    # start drawing on image
    draw = ImageDraw.Draw(image)
    
    fontsize = 1  # starting font size
    # portion of image width you want text width to be
    img_fraction = 0.50
    font = ImageFont.truetype(fontFile, fontsize)
    
    while font.getsize(bidi_text)[0] < img_fraction*image.size[0]:
        # iterate until the text size is just larger than the criteria
        fontsize += 1
        font = ImageFont.truetype(fontFile, fontsize)
        
    # optionally de-increment to be sure it is less than criteria
    fontsize -= 1
    font = ImageFont.truetype(fontFile, fontsize)
    
    draw.text(img_center, bidi_text, (255,255,0), font=font, align='right')
    
    im = generate_captioned(bidi_text, image_path=imageFile, size=(610, 780),
                            font_path=fontFile, filter_color=(0, 0, 0, 40))
    im.convert('RGB').save(f'cap_imgs/{c}.jpg')
    

    # save it
    image.save(f'imgs/{c}.jpg')
# Out:
# ----------
#
# ----------
#
# *********************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5244\1545538093.py in <module>
#      42         # iterate until the text size is just larger than the criteria
#      43         fontsize += 1
# ---> 44         font = ImageFont.truetype(fontFile, fontsize)
#      45
#      46     # optionally de-increment to be sure it is less than criteria
#
# ~\anaconda3\lib\site-packages\PIL\ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     957
#     958     try:
# --> 959         return freetype(font)
#     960     except OSError:
#     961         if not is_path(font):
#
# ~\anaconda3\lib\site-packages\PIL\ImageFont.py in freetype(font)
#     954
#     955     def freetype(font):
# --> 956         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     957
#     958     try:
#
# ~\anaconda3\lib\site-packages\PIL\ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     216
#     217         if layout_engine not in (Layout.BASIC, Layout.RAQM):
# --> 218             layout_engine = Layout.BASIC
#     219             if core.HAVE_RAQM:
#     220                 layout_engine = Layout.RAQM
#
# KeyboardInterrupt:

# %%
def create_table(files1, files2, files3):
    header = """
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>App</title>
</head>
    
<body>
    <h1 style="text-align: center;">Anne Shirley Quotes</h1>

 <table style="margin-left: auto; margin-right: auto;">
    <thead>
        <tr>
            <th>Original Image</th>
            <th>Wallpaper Image</th>
            <th>Final Image</th>
        </tr>
    </thead>

    <tbody>
    """
    
    rows=""
    for f1, f2, f3 in zip(files1, files2, files3):

        rows += f"""
    <tr>
        <td><img src="{f1}" alt="" width="300px" height="300px"></td>
        <td><img src="{f2}" alt="" width="300px" height="300px"></td>
        <td><img src="{f3}" alt="" width="300px" height="300px"></td>
    </tr>"""
        
        
    footer = """
         </tbody>
    </table>

</body>
</html>
        """

    return header, rows, footer

# %%
# iterate over files
anne_files = Path('anne').glob('*')
wallpaper_files = Path('wallpapers').glob('*')
imgs_files = Path('imgs').glob('*')

h, r, f =create_table(anne_files, wallpaper_files, imgs_files)

# %%
html = open('index.html', 'w')
html.write(h+r+f)
html.close()
